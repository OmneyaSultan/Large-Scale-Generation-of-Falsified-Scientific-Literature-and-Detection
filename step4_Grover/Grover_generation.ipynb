# %%
# Code collected and updated from: https://gist.github.com/kastnerkyle/f62e9c8e39a88ff90167478bac6bcd25

# %%
# Set up for Grover:
# !cd /content && rm -rf grover && git clone https://github.com/rowanz/grover.git
# %cd /content/grover
# !pip install -r requirements-gpu.txt
# !python download_model.py large
# Out:
# Cloning into 'grover'...
# remote: Enumerating objects: 104, done.
# remote: Total 104 (delta 0), reused 0 (delta 0), pack-reused 104
# Receiving objects: 100% (104/104), 672.23 KiB | 15.63 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/grover
# ...
#      |████████████████████████████████| 10.1 MB 27.7 MB/s
# ...
#      |████████████████████████████████| 644 kB 62.4 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 47.6 MB/s
# ...
#      |████████████████████████████████| 17.3 MB 144 kB/s
# ...
#      |████████████████████████████████| 3.2 MB 59.1 MB/s
# ...
#      |████████████████████████████████| 345.0 MB 3.7 kB/s
# ...
#      |████████████████████████████████| 48 kB 6.2 MB/s
# ...
#      |████████████████████████████████| 57 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.5 MB/s
# ...
#      |████████████████████████████████| 367 kB 67.8 MB/s
# ...
#      |████████████████████████████████| 58 kB 7.7 MB/s
# ...

# %%
# Set up for Grover generation:
# !pip install numpy --upgrade
# !pip install tensorflow-gpu==1.15.0
# !pip install tensorboard==2.8.0
from tensorflow.python.util.tf_export import keras_export
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 28.4 MB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.16.2
#     Uninstalling numpy-1.16.2:
#       Successfully uninstalled numpy-1.16.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# xarray 0.18.2 requires pandas>=1.0, but you have pandas 0.24.2 which is incompatible.
# tensorflow 2.8.0 requires tensorboard<2.9,>=2.8, but you have tensorboard 1.13.1 which is incompatible.
# spacy 2.2.4 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.31.1 which is incompatible.
# plotnine 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# mizani 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# ...

# %%
# Run the generator 3 times to produce 642 outputs, of which we'll take the first 500:
for i in range(3):
  output_fn = 'output' + str(i) + '.jsonl'

  # !PYTHONPATH=$(pwd) python sample/contextual_generate.py -model_config_fn lm/configs/large.json \
  -model_ckpt models/large/model.ckpt \
  -metadata_fn /content/completejsonl.jsonl \
  -out_fn $output_fn
# Out:
# WARNING:tensorflow:From /content/grover/lm/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /content/grover/lm/modeling.py:87: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
#
# ~~
# batch size=1, max batch size=16, num chunks=1, batch size per chunk=1
# ~~
#
# WARNING:tensorflow:From sample/contextual_generate.py:104: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From sample/contextual_generate.py:106: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-04-04 17:44:21.487980: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-04-04 17:44:21.493505: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# ...
