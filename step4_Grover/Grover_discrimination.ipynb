# %% [markdown]
# # Code collected and updated from: https://gist.github.com/kastnerkyle/f62e9c8e39a88ff90167478bac6bcd25

# %%
# Set up for Grover via Github:
# !cd /content && rm -rf grover && git clone https://github.com/rowanz/grover.git
# %cd /content/grover
# !pip install -r requirements-gpu.txt
# Out:
# Cloning into 'grover'...
# remote: Enumerating objects: 104, done.
# remote: Total 104 (delta 0), reused 0 (delta 0), pack-reused 104
# Receiving objects: 100% (104/104), 672.23 KiB | 2.40 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/grover
# ...
#      |████████████████████████████████| 10.1 MB 7.9 MB/s
# ...
#      |████████████████████████████████| 644 kB 47.8 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 42.0 MB/s
# ...
#      |████████████████████████████████| 17.3 MB 30.7 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 45.6 MB/s
# ...
#      |████████████████████████████████| 345.0 MB 3.8 kB/s
# ...
#      |████████████████████████████████| 48 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 57 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 367 kB 73.5 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.8 MB/s
# ...

# %%
# Set up for Grover discrimination:
# !pip install numpy --upgrade
# !pip install tensorflow-gpu==1.15.0
# !pip install tensorboard==2.8.0
from tensorflow.python.util.tf_export import keras_export
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 347 kB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.16.2
#     Uninstalling numpy-1.16.2:
#       Successfully uninstalled numpy-1.16.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# xarray 0.18.2 requires pandas>=1.0, but you have pandas 0.24.2 which is incompatible.
# tensorflow 2.8.0 requires tensorboard<2.9,>=2.8, but you have tensorboard 1.13.1 which is incompatible.
# spacy 2.2.4 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.31.1 which is incompatible.
# plotnine 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# mizani 0.6.0 requires pandas>=0.25.0, but you have pandas 0.24.2 which is incompatible.
# ...

# %%
# Mount Google Drive to Colab:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Run the Grover discriminator:
#!PYTHONPATH=$(pwd) python discrimination/run_discrimination.py -input_data /content/drive/MyDrive/Grover_Discrimination/Discrimination_Input.jsonl \
#  -config_file lm/configs/large.json \
#  -output_dir /content/drive/MyDrive/Grover_Discrimination/ -predict_test

# !PYTHONPATH=$(pwd) python discrimination/run_discrimination.py \
  -input_data /content/drive/MyDrive/Grover_Discrimination/Discrimination_Input.jsonl \
  -config_file lm/configs/large.json -output_dir /content/drive/MyDrive/Grover_Discrimination/ \
  -max_seq_length 500 -batch_size 1 -predict_test
# Out:
# WARNING:tensorflow:From /content/grover/lm/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From discrimination/run_discrimination.py:339: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From discrimination/run_discrimination.py:140: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0405 19:52:41.560422 140389691602816 module_wrapper.py:139] From discrimination/run_discrimination.py:140: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From discrimination/run_discrimination.py:140: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# View the output: predictions of whether the sample text is machine or human, i.e. "['machine', 'human']"
import numpy
numpy.load("/content/drive/MyDrive/Grover_Discrimination/test-probs.npy")
# Out:
# array([[0.3557071 , 0.64429283],
#        [0.34264848, 0.6573515 ],
#        [0.46787757, 0.53212243],
#        ...,
#        [0.        , 0.        ],
#        [0.        , 0.        ],
#        [0.        , 0.        ]], dtype=float32)
